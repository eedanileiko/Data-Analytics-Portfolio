# %% [markdown]
# <a href="https://colab.research.google.com/github/eedanileiko/Data-Analytics-Portfolio/blob/main/homework_practice_01_pandas_Danileiko_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Машинное обучение 1, ПМИ ФКН ВШЭ
#
# ## Практическое домашнее задание 1
#
# ### Общая информация
#
# Дата выдачи: 15.09.2025
#
# Мягкий дедлайн: 23:59MSK 29.09.2025
#
# Жесткий дедлайн: 23:59MSK 03.10.2025

# %% [markdown]
# ### О задании
#
# Задание состоит из двух разделов, посвященных работе с табличными данными с помощью библиотеки `pandas` и визуализации с помощью `matplotlib`. В первом разделе вам предстоит выполнить базовые задания с помощью вышеуказанных библиотек, а во втором распределить студентов по курсам. Баллы даются за выполнение отдельных пунктов. Задачи в рамках одного раздела рекомендуется решать в том порядке, в котором они даны в задании.
#
# Задание направлено на освоение jupyter notebook (будет использоваться в дальнейших заданиях), библиотек pandas и matplotlib.
#
# ### Оценивание и штрафы
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи). Максимально допустимая оценка за работу — 10 баллов без учёта бонусов. Сдавать задание после жёсткого дедлайна нельзя.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов (подробнее о плагиате см. на странице курса). Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник (скорее всего вы будете не единственным, кто это нашел, поэтому чтобы исключить подозрение в плагиате, необходима ссылка на источник).
#
# ### Формат сдачи
# Задания сдаются через систему Anytask. Инвайт можно получить у семинариста или ассистента. Присылать необходимо ноутбук с выполненным заданием. Сам ноутбук называйте в формате `homework-practice-01-pandas-Username.ipynb`, где Username — ваша фамилия.
#
# Для удобства проверки самостоятельно посчитайте свою максимальную оценку (исходя из набора решенных задач) и укажите ниже.
#
# Оценка: <font color='blue'>10/10</font>.

# %% [markdown]
# ## 0. Введение

# %% [markdown]
# Сейчас мы находимся в jupyter-ноутбуке (или ipython-ноутбуке). Это удобная среда для написания кода, проведения экспериментов, изучения данных, построения визуализаций и других нужд, не связанных с написанием production-кода.
#
# Ноутбук состоит из ячеек, каждая из которых может быть либо ячейкой с кодом, либо ячейкой с текстом размеченным и неразмеченным. Текст поддерживает markdown-разметку и формулы в Latex.
#
# Для работы с содержимым ячейки используется *режим редактирования* (*Edit mode*, включается нажатием клавиши **Enter** после выбора ячейки), а для навигации между ячейками искользуется *командный режим* (*Command mode*, включается нажатием клавиши **Esc**). Тип ячейки можно задать в командном режиме либо с помощью горячих клавиш (**y** to code, **m** to markdown, **r** to edit raw text), либо в меню *Cell -> Cell type*.
#
# После заполнения ячейки нужно нажать *Shift + Enter*, эта команда обработает содержимое ячейки: проинтерпретирует код или сверстает размеченный текст.

# %%
# ячейка с кодом, при выполнении которой появится output
2 + 2

# %% [markdown]
# Ячейка с неразмеченным текстом.

# %% [markdown]
# Попробуйте создать свои ячейки, написать какой-нибудь код и текст какой-нибудь формулой.

# %%
a=1+1
a
# Out:
# 2

# %% [markdown]
# [Здесь](https://athena.brynmawr.edu/jupyter/hub/dblank/public/Jupyter%20Notebook%20Users%20Manual.ipynb) находится <s>не</s>большая заметка о используемом языке разметки Markdown. Он позволяет:
#
# 0. Составлять упорядоченные списки
# 1. Выделять *текст* <s>при</s> **необходимости**
# 2. Добавлять [ссылки](http://imgs.xkcd.com/comics/the_universal_label.png)
#
#
# * Составлять неупорядоченные списки
#
# Делать вставки с помощью LaTex:
#
# $
# \left\{
# \begin{array}{ll}
# x = 16 \sin^3 (t) \\
# y = 13 \cos (t) - 5 \cos (2t) - 2 \cos (3t) - \cos (4t) \\
# t \in [0, 2 \pi]
# \end{array}
# \right.$

# %% [markdown]
# А ещё можно вставлять картинки, или гифки, или что захотите:
#
# <img src="https://media1.tenor.com/images/9b8fbe9214504bcf6c60fe4e4f7e114e/tenor.gif?itemid=5416416" style="width: 400px">

# %% [markdown]
# ### Google Colab

# %% [markdown]
# Что за колаб?
#
# **Google Colab (Colaboratory)** это **Jupyter Notebook + Cloud + Google Drive.**
#
# Компания Google предоставляет возможность бесплатно запускать ноутбуки (предварительно загрузив их на свой гугл-диск) прямо в облаке. При этом вам не требуется установка никаких пакетов на свою машину, а работать можно прямиком из браузера. Вот ссылка:

# %% [markdown]
# https://colab.research.google.com

# %% [markdown]
# При использовании вы увидите много сходств с jupyter ноутбуком. Одним из преимуществ является доступность GPU, соответствующую опцию можно активировать в настройках сервиса. При желании вы сможете найти в интернете много туториалов по использованию или разобраться самостоятельно

# %% [markdown]
# ### Kaggle
#
# Альтернативой является **Kaggle**, он же площадка для самых разных соревнований по машинному обучению
#
# Он, как и колаб, предоставляет бесплатный GPU, и даже не один, с чётким лимитом в 30 часов в неделю (colab может его внезапно отобрать, kaggle - нет) более мощные CPU с большим числом ядер, и больше Гб ОЗУ (раз так в 2.5)
#
# https://www.kaggle.com
#
# К сожалению мир не идеален, недостатки следующие:
# - необходимость загружать датасеты через специальную кнопочку
# - невозможность использовать свои скрипты и модули :(
# - нужно тыкать техподдержку, чтобы создать аккаунт из России

# %% [markdown]
# ## 1. Табличные данные и Pandas [4 балла]

# %% [markdown]
# Pandas — удобная библиотека для работы с табличными данными в Python, если данных не слишком много и они помещаются в оперативную память вашего компьютера. Несмотря на неэффективность реализации и некоторые проблемы, библиотека стала стандартом в анализе данных.
#
# Основной объект в `pandas` — это `pd.DataFrame`, представляющий собой таблицу с именованными колонками различных типов, индексом (может быть многоуровневым). DataFrame можно создавать, считывая таблицу из файла или задавая вручную из других объектов.
#
# В этой части потребуется выполнить несколько небольших заданий. Можно пойти двумя путями: сначала изучить материалы, а потом приступить к заданиям, или же разбираться "по ходу". Выбирайте сами.
#
# Материалы:
# 1. [Pandas за 10 минут из официального руководства](http://pandas.pydata.org/pandas-docs/stable/10min.html)
# 2. [Документация](http://pandas.pydata.org/pandas-docs/stable/index.html) (стоит обращаться, если не понятно, как вызывать конкретный метод)
# 3. [Примеры использования функционала](http://nbviewer.jupyter.org/github/justmarkham/pandas-videos/blob/master/pandas.ipynb)
#
# Многие из заданий можно выполнить несколькими способами. Не существуют единственно верного, но попробуйте максимально задействовать арсенал pandas и ориентируйтесь на простоту и понятность вашего кода. Мы не будем подсказывать, что нужно использовать для решения конкретной задачи, попробуйте находить необходимый функционал сами (название метода чаще всего очевидно). В помощь вам документация, поиск и StackOverflow.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <span style="color:red">Перед выполнением задания необходимо ознакомиться с первым семинаром (seminars/sem01-pandas.ipynb) </span>.
#
# Это поможет вам получить общее понимание происходяшего и успешнее справиться с заданием.
#
# Также успешному выполнению способствует внимательное чтение текста задания от начала до конца.
#
# Удачи!

# %% [markdown]
# Скачаем подготовленные на семинаре данные: <font color='blue'>еле скачала...</font>

# %% [markdown]
# ##### В первой части задания (до раздела "Распределение студентов по курсам") использование циклов запрещается и повлечет за собой снижение оценки. Использование <code>vectorize</code> и  <code>apply</code>, <code>apply_along_axis</code> и всего, где можно применить лямбда-функции (`assign`, `map`, ...) крайне нежелательно

# %% [markdown]
# Для каждой задачи из этого раздела вы должны написать код для получения ответа, а также дать текстовый ответ, если он предполагается.
#
# На некоторые вопросы вы можете получить путём пристального взгляда на таблицу, но это не будет засчитываться. Вы в любом случае должны получить ответ с помощью кода.

# %% [markdown]
# #### 1. [0.5 баллов] Откройте файл с таблицей (не забудьте про её формат). Выведите 3 последних строки.
#
# Посмотрите на данные и скажите, что они из себя представляют, сколько в таблице строк, какие столбцы? (на это не надо отвечать, просто подумайте об этом)

# %%
df = pd.read_excel('end_seminar (1).xlsx')
df.tail(3)
# Out:
#                   timestamp  \
# 426 2024-08-19 11:49:43.000
# 427 2024-08-13 14:58:30.000
# 428 2024-08-13 18:35:25.235
#
#                                                     id  rating  group_22  \
# 426  77b2b19d26b7f160c1938369197f7cac590b2e0cfcac3b...    1232       NaN
# 427  6dafd9a56d08aeb419166d314b0cd6f3107ae5e8dbd636...     961       NaN
# 428  4bf710d7b89064e1a3cbcc69b7ca67c20d6181dc72ad35...    1374       NaN
#
#      is_mi                                             fall_1  \
# 426    NaN  Принятие решений в условиях риска и неопределе...
# 427    NaN                      Основы информационного поиска
# 428    NaN            Трансформерные и мультимодальные модели
#
#                                       fall_2                       fall_3  \
# 426       Основы разработки компьютерных игр  Введение в платформы данных
# 427                            Дизайн систем  Язык программирования Scala
# 428  Глубинное обучение для текстовых данных     Self-supervised Learning
#
# ...

# %% [markdown]
# ### Ответьте на вопросы:
# 1. Сколько было уникальных пользователей из групп 22-го года набора, а сколько из групп 21-го года?

# %%
print(df['group_22'].nunique())
print(df['group_21'].nunique())
# Out:
# 10
# 9

# %% [markdown]
# 2. Есть ли уникальные студенты с равными перцентилями?

# %%
df['percentile'].nunique()-df['percentile'].notnull().count()
# Out:
# -100

# %% [markdown]
# <font color='blue'>Есть, так как количество ненулевых персентилей совпадает с количеством уникальных персентилей, значит не все они униркальны, то есть некоторые повторяются.</font>

# %% [markdown]
# #### 2. [0.5 балла] Есть ли в данных пропуски? В каких колонках? Сколько их в каждой из этих колонок?

# %%
df.isnull().sum()
# Out:
# timestamp          0
# id                 0
# rating             0
# group_22         159
# is_mi            403
# fall_1             0
# fall_2             0
# fall_3             0
# spring_1          48
# spring_2          48
# spring_3          48
# is_first_time      0
# percentile         0
# group_21         270
# blended          270
# is_ml_student    254
# dtype: int64

# %% [markdown]
# Заполните пропуски пустой строкой для строковых колонок, нулём для числовых и False для булевых (постарайтесь избежать перечисления названий всех столбцов).

# %%
df[df.columns].dtypes #это просто для проверки
# Out:
# timestamp        datetime64[ns]
# id                       object
# rating                    int64
# group_22                float64
# is_mi                   float64
# fall_1                   object
# fall_2                   object
# fall_3                   object
# spring_1                 object
# spring_2                 object
# spring_3                 object
# is_first_time            object
# percentile              float64
# group_21                float64
# blended                  object
# is_ml_student           float64
# dtype: object

# %%
df[df.select_dtypes(include=['object']).columns]=df[df.select_dtypes(include=['object']).columns].fillna('')
df[df.select_dtypes(include=['float64']).columns]=df[df.select_dtypes(include=['float64']).columns].fillna(0)
df[df.select_dtypes(include=['bool']).columns]=df[df.select_dtypes(include=['bool']).columns].fillna(False)
df.head()
# Out:
#             timestamp                                                 id  \
# 0 2024-08-12 00:01:06  8a95d7276b95b8b9c4cf8a5b402e98617ad7452977f6e6...
# 1 2024-08-14 00:00:22  289897d0cf42b4b42c50300f94b8b86f913174ae972d96...
# 2 2024-08-13 18:16:33  01f548f29a80a6f35b8ce1bdfdf723e2ba70a9c074c2f9...
# 3 2024-08-14 10:22:37  68e3e62f6e017e43094bb63b4dde0b0229564cece838b5...
# 4 2024-08-14 20:52:05  aac63ca42c5701a219d0e4f3289e17ed3160d5a2279790...
#
#    rating  group_22  is_mi                          fall_1  \
# 0     737     226.0    0.0  Разработка микросервисов на Go
# 1     486    2210.0    0.0          Распределенные системы
# 2     494     223.0    0.0     Statistical Learning Theory
# 3     753     225.0    0.0  Разработка микросервисов на Go
# 4     685     221.0    0.0  Типы в языках программирования
#
#                           fall_2                              fall_3  \
# 0                       Язык SQL              Распределенные системы
# ...

# %% [markdown]
# #### 3. [0.5 балла] Посмотрите повнимательнее на колонку 'is_first_time'.
#
# Каково процентное соотношение ответов? Сколько из них "Нет"?

# %%
df['is_first_time'][df['is_first_time']=="Да"].count()
# Out:
# 407

# %%
df['is_first_time'][df['is_first_time']=="Нет"].count()
# Out:
# 22

# %%
df['is_first_time'].value_counts()
# Out:
# is_first_time
# Да     407
# Нет     22
# Name: count, dtype: int64

# %%
df['is_first_time'].value_counts(normalize=True)*100
# Out:
# is_first_time
# Да     94.871795
# Нет     5.128205
# Name: proportion, dtype: float64

# %% [markdown]
# Если вы найдете повторные обращения студентов, оставьте только самую позднюю версию. В дальнейших заданиях используйте версию данных без повторов. Уберите колонку is_mi, она нам не пригодится
#
# <i>Обращения со значением "Нет" в 'is_first_time' могут быть как повторными, так и первичными, поскольку поле заполняли сами студенты.</i>

# %%
df_sort=df.sort_values(['id','timestamp'],ascending=[True,False])
df_new=df_sort.drop_duplicates(subset=['id'],keep='first')
df_new= df_new.drop(columns=['is_mi'])

# %%
df_new['is_first_time'].value_counts()
# Out:
# is_first_time
# Да     403
# Нет     15
# Name: count, dtype: int64

# %% [markdown]
# <font color='blue'>Значения изменились, значит повторы были. Приведем все это в проценты:</font>

# %%
df_new['is_first_time'].value_counts(normalize=True)*100
# Out:
# is_first_time
# Да     96.411483
# Нет     3.588517
# Name: proportion, dtype: float64

# %% [markdown]
# #### 4. [0.5 балла] Какие  blended-курсы для четверокурсников существуют? На какой blended-курс записалось наибольшее количество студентов? На каком из blended-курсов собрались студенты с самым высоким средним рейтингом (выведите этот курс и количество студентов на нем)?

# %% [markdown]
# <font color='blue'>Какие blended-курсы существуют и сколько людей на них записалось:</font>

# %%
popular=df_new['blended'].value_counts().drop('')
popular
# Out:
# blended
# Протоколы доказательств с нулевым разглашением    44
# ML System Design                                  38
# Соревновательный анализ данных                    26
# Продуктовый подход к анализу данных               25
# Безопасность систем на базе LLM                   13
# Введение в дифференциальную геометрию             13
# Name: count, dtype: int64

# %% [markdown]
# <font color='blue'>Отдельно выведем название курса, на который записалось большее количество людей,и количество людей на нем</font>

# %%
popular.index[0]
# Out:
# 'Протоколы доказательств с нулевым разглашением'

# %%
popular.iloc[0]
# Out:
# 44

# %% [markdown]
#  <font color='blue'>На каком из blended-курсов собрались студенты с самым высоким средним рейтингом (выведите этот курс и количество студентов на нем)?</font>

# %% [markdown]
#  <font color='blue'>Выведем средний рейтинг каждого курса:</font>

# %%
databl=df_new.groupby('blended')['rating'].sum()/df_new.groupby('blended')['rating'].count()
databl=databl.drop('')
databl
# Out:
# blended
# ML System Design                                  1202.315789
# Безопасность систем на базе LLM                   1163.307692
# Введение в дифференциальную геометрию             1138.538462
# Продуктовый подход к анализу данных               1249.280000
# Протоколы доказательств с нулевым разглашением    1146.500000
# Соревновательный анализ данных                    1207.846154
# Name: rating, dtype: float64

# %% [markdown]
# <font color='blue'>Значение самого высокого рейтинга:</font>

# %%
print(databl.min())
# Out:
# 1138.5384615384614

# %% [markdown]
# <font color='blue'>Название и значение этого курса:</font>

# %%
databl.loc[databl==databl.min()]
# Out:
# blended
# Введение в дифференциальную геометрию    1138.538462
# Name: rating, dtype: float64

# %% [markdown]
# #### 5. [1 балл] Выясните, есть ли студенты с абсолютно одинаковыми предпочтениями по всем курсам.
#
# Для этого сформируйте таблицу, где для каждого возможного набора курсов посчитано количество студентов, выбравших такой набор, и оставьте только строки где это количество больше 1.
#
# В данном случае набор курсов задается упорядоченным множеством ('fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended'). Элемент blended будет нулевым для 3-го курса.

# %% [markdown]
# <font color='blue'>**Ответ**: есть.</font>

# %%
columns=['fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended']
df_new['blended']=df_new['blended'].fillna(0)
df_mega_new=df_new.groupby(columns).size().reset_index(name='count')
df_mega_new['blended'].value_counts()
# Out:
# blended
#                                                   238
# Протоколы доказательств с нулевым разглашением     41
# ML System Design                                   38
# Соревновательный анализ данных                     26
# Продуктовый подход к анализу данных                25
# Безопасность систем на базе LLM                    13
# Введение в дифференциальную геометрию              13
# Name: count, dtype: int64

# %%
df_mega_new=df_mega_new[df_mega_new['count']>1]
df_mega_new.head()
# Out:
#                                fall_1                              fall_2  \
# 13        Statistical Learning Theory       Основы информационного поиска
# 60   Безопасность компьютерных систем  Основы разработки компьютерных игр
# 134                     Дизайн систем    Безопасность компьютерных систем
# 135                     Дизайн систем    Безопасность компьютерных систем
# 142                     Дизайн систем              Операционные системы 2
#
#                                  fall_3  \
# 13                             Язык SQL
# 60                             Язык SQL
# 134  Основы разработки компьютерных игр
# 135  Основы разработки компьютерных игр
# 142       Основы информационного поиска
#
#                                      spring_1  \
# 13    Дополнительные главы машинного обучения
# 60                          Компьютерные сети
# 134                Децентрализованные системы
# 135                Децентрализованные системы
# ...

# %% [markdown]
# #### 6. [0.5 балла] Найдите курсы по выбору, на которые записывались как студенты 22-го года набора, так и студенты 21-го года.

# %%
col=['fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3']
data_21=df_new[df_new['group_22']==0][col]
data_22=df_new[df_new['group_21']==0][col]
courses_for_all=(set(data_21['fall_1'])|set(data_21['fall_2'])|set(data_21['fall_3'])|set(data_21['spring_1'])|set(data_21['spring_2'])|set(data_21['spring_3']))&(set(data_22['fall_1'])|set(data_22['fall_2'])|set(data_22['fall_3'])|set(data_22['spring_1'])|set(data_22['spring_2'])|set(data_22['spring_3']))
print(courses_for_all)
# Out:
# {'Основы информационного поиска', 'Statistical Learning Theory', 'Специальные разделы матричного анализа', 'Стохастический анализ', 'Математические основы нейросетевых моделей', 'Безопасность компьютерных систем', 'Типы в языках программирования', 'Введение в платформы данных', 'Принятие решений в условиях риска и неопределенности', 'Основы тензорных вычислений', 'Основы разработки компьютерных игр', 'Язык программирования Scala', 'Интегральные уравнения в задачах математического моделирования', 'Операционные системы 2'}

# %% [markdown]
# Методом исключения найдите курсы, которые предлагались только студентам 22-го года и только студентам 21-го года.

# %% [markdown]
# <font color='blue'>Курсы, которые предлагались только студентам 22-го года **И** только студентам 21-го года.</font>

# %%
course_21=(set(data_21['fall_1'])|set(data_21['fall_2'])|set(data_21['fall_3'])|set(data_21['spring_1'])|set(data_21['spring_2'])|set(data_21['spring_3']))
course_22=(set(data_22['fall_1'])|set(data_22['fall_2'])|set(data_22['fall_3'])|set(data_22['spring_1'])|set(data_22['spring_2'])|set(data_22['spring_3']))
print((course_21-courses_for_all)|(course_22-courses_for_all))
# Out:
# {'', 'Язык программирования Go', 'Машинное обучение 2', 'Глубинное обучение в анализе графовых данных', 'Системы баз данных', 'Прикладная статистика в машинном обучении', 'Промышленное программирование на Haskell', 'Разработка микросервисов на Go', 'Символьные вычисления', 'Аналитика данных', 'Компьютерные сети', 'Эксплуатация и надёжность программных систем', 'Современные языковые модели', 'Количественные финансы', 'Топологический анализ данных', 'Машинное обучение в прикладных задачах', 'Глубинное обучение для текстовых данных', 'Теория и практика онлайн-экспериментов', 'Развёртывание ML-моделей в высоконагруженных системах', 'Промышленное программирование на языке Java', 'Генеративные модели на основе диффузии / Diffusion-Based Generative Models', 'Байесовские методы в машинном обучении', 'Глубинное обучение в обработке звука', 'Трехмерное компьютерное зрение', 'Рекомендательные системы', 'Децентрализованные системы', 'Глубинное обучение в естественных науках', 'Моделирование врем
# ...

# %% [markdown]
# <font color='blue'>Список курсов для 21 года.</font>

# %%
print((course_21-courses_for_all))
# Out:
# {'Глубинное обучение в анализе графовых данных', 'Промышленное программирование на Haskell', 'Символьные вычисления', 'Эксплуатация и надёжность программных систем', 'Современные языковые модели', 'Глубинное обучение для текстовых данных', 'Теория и практика онлайн-экспериментов', 'Развёртывание ML-моделей в высоконагруженных системах', 'Генеративные модели на основе диффузии / Diffusion-Based Generative Models', 'Байесовские методы в машинном обучении', 'Глубинное обучение в обработке звука', 'Трехмерное компьютерное зрение', 'Децентрализованные системы', 'Дизайн систем', 'Методы сжатия и передачи медиаданных', 'Теория сложных систем', 'Обучение с подкреплением', 'Конфликты и кооперация (преподается на английском языке)', 'Генеративные модели в машинном обучении', 'Self-supervised Learning', 'Генеративные модели на основе диффузии', 'Трансформерные и мультимодальные модели', 'Эффективные системы глубинного обучения'}

# %% [markdown]
# <font color='blue'>Список курсов для 21 года.</font>

# %%
print((course_22-courses_for_all))
# Out:
# {'', 'Язык программирования Go', 'Машинное обучение 2', 'Системы баз данных', 'Прикладная статистика в машинном обучении', 'Разработка микросервисов на Go', 'Аналитика данных', 'Компьютерные сети', 'Количественные финансы', 'Топологический анализ данных', 'Машинное обучение в прикладных задачах', 'Промышленное программирование на языке Java', 'Рекомендательные системы', 'Глубинное обучение в естественных науках', 'Моделирование временных рядов', 'Лингвистика для программистов', 'Комбинаторная оптимизация', 'Функциональное программирование', 'Шадовский Go', 'Go от шада', 'Язык SQL', 'ШАД RL', 'Генеративные модели в машинном обучении (углубленный курс)', 'Распределенные системы', 'Дополнительные главы машинного обучения'}

# %% [markdown]
# Видите ли вы что-то необычное в получившихся списках? (менять ничего не нужно, просто подумайте)
#
# **Ответ:** <font color='blue'>в списки курсов 22 года попала пустая строка.</font>

# %% [markdown]
# ### Визуализации и matplotlib

# %% [markdown]
# При работе с данными часто неудобно делать какие-то выводы, если смотреть на таблицу и числа в частности, поэтому важно уметь визуализировать данные. Здесь будут описаны ключевые правила оформления графиков для **всех** домашних заданий.
#
# У matplotlib, конечно же, есть [документация](https://matplotlib.org/users/index.html) с большим количеством [примеров](https://matplotlib.org/examples/), но для начала достаточно знать про несколько основных типов графиков:
# - plot — обычный поточечный график, которым можно изображать кривые или отдельные точки;
# - hist — гистограмма, показывающая распределение некоторой величины;
# - scatter — график, показывающий взаимосвязь двух величин;
# - bar — столбцовый график, показывающий взаимосвязь количественной величины от категориальной.
#
# В этом задании вы попробуете построить один из них. Не забывайте про базовые принципы построения приличных графиков:
# - оси должны быть подписаны, причём не слишком мелко;
# - у графика должно быть название;
# - если изображено несколько графиков, то необходима поясняющая легенда;
# - все линии на графиках должны быть чётко видны (нет похожих цветов или цветов, сливающихся с фоном);
# - если отображена величина, имеющая очевидный диапазон значений (например, проценты могут быть от 0 до 100), то желательно масштабировать ось на весь диапазон значений (исключением является случай, когда вам необходимо показать малое отличие, которое незаметно в таких масштабах);
# - сетка на графике помогает оценить значения в точках на глаз, это обычно полезно, поэтому лучше ее отрисовывать;
# - если распределение на гистограмме имеет тяжёлые хвосты, лучше использовать логарифмическую шкалу.
#
# Еще одна билиотека для визуализации: [seaborn](https://jakevdp.github.io/PythonDataScienceHandbook/04.14-visualization-with-seaborn.html) (обычно сокращается до sns). Это настройка над matplotlib, иногда удобнее и красивее делать визуализации через неё.
#
# **5 пунктов после которых ваши графики не будут прежними:**
# - для красивой картинки <code>%config InlineBackend.figure_format = 'retina'</code>
# - задаем размер (почти) всех графиков (можно выбрать другие значения) <code>plt.rcParams['figure.figsize'] = 8, 5</code>
# - размер шрифта подписей графиков <code>plt.rcParams['font.size'] = 12</code>
# - формат в котором сохраняется изображение <code>mpl.rcParams['savefig.format'] = 'pdf'</code>
# - sns – seaborn, добавляет решетку <code>sns.set_style('darkgrid')</code>
#
# Добавьте эти функции в ячейку ниже. Каждый график все равно придется настраивать отдельно, но указанные строчки позволят значительно упростить процесс.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# your code

# %%
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['figure.figsize'] = 8, 5
plt.rcParams['font.size'] = 12
mpl.rcParams['savefig.format'] = 'pdf'
sns.set_style('darkgrid')

# %% [markdown]
# #### 7. [0.5 балла] Постройте график средних рейтингов по дням получения ответов (bar plot).

# %%
data7=df_new[['timestamp','rating']]
data7['timestamp']=data7['timestamp'].dt.to_period('D')
# Out:
# C:\Users\Kate\AppData\Local\Temp\ipykernel_8488\1029410280.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data7['timestamp']=data7['timestamp'].dt.to_period('D')

# %%
data7=data7.groupby('timestamp')['rating'].sum()/data7.groupby('timestamp')['rating'].count()
data7.head()
# Out:
# timestamp
# 2024-08-11    767.761905
# 2024-08-12    817.594595
# 2024-08-13    736.111111
# 2024-08-14    851.175676
# 2024-08-15    975.625000
# Freq: D, Name: rating, dtype: float64

# %%
data7.index=data7.index.to_timestamp()

# %%
plt.figure(figsize=(10,5))
matplotlib.pyplot.bar(data7.index,data7)
plt.title('График средних рейтингов по дням получения ответов')
plt.xlabel('Дни получения ответов')
plt.ylabel('Средние рейтинги')
plt.show()
plt.close()

# %% [markdown]
# Сохраните график в формате pdf (так он останется векторизованным).

# %%
plt.figure(figsize=(10,5))
matplotlib.pyplot.bar(data7.index,data7)
plt.title('График средних рейтингов по дням получения ответов')
plt.xlabel('Дни получения ответов')
plt.ylabel('Средние рейтинги')
plt.savefig('HW1_plt')

# %% [markdown]
# ## 2. Распределение студентов по курсам. (6 баллов + 1 бонус)

# %% [markdown]
# #### **<span style="color:red">‼️ВНИМАТЕЛЬНО ИЗУЧИТЕ ТЕКСТ НИЖЕ‼️</span>.**
#
# <span style="color:orange">Если во время выполнения заданий у вас вознинут вопросы -- еще раз перечитайте текст целиком, скорее всего ответы уже содержатся в нем.</span>
#
# Теперь вам нужно распределить студентов по осенним курсам по выбору, учитывая их предпочтения.

# %% [markdown]
# Теперь вам нужно распределить студентов по осенним курсам по выбору, учитывая их предпочтения.

# %% [markdown]
# ## 📌 **Алгоритм распределения студентов по курсам**:
# 1. По умолчанию на каждой дисциплине по выбору у 3 и 4 курсов может учиться 1 группа (до 30 студентов). Исключения описаны ниже. На blended-дисциплинах для четверокурсников количество мест не ограничено.
# 2. Проводится первая волна отбора. Для каждой дисциплины формируется список тех, кто указал её первым приоритетом (если студент должен выбрать два курса по выбору, то для него дисциплины, которые он указал первым и вторым приоритетом, рассматриваются как дисциплины первого приоритета). Если желающих больше, чем мест, то выбирается топ по перцентилю рейтинга.
# 3. На дисциплинах, где остались места после первой волны, формируются списки тех, кто выбрал их вторым приоритетом, и места заполняются лучшими по перцентили рейтинга студентами. После этого проводится такая же процедура для дисциплин третьего приоритета.
# 4. Если студент не попал на необходимое количество курсов по итогам трёх волн, с ним связывается учебный офис и решает вопрос в индивидуальном порядке.

# %% [markdown]
# ## ☝️ **Обращаем ваше внимание на следующие детали:**
#
# - Конкурс на каждый курс общий для 3-го и 4-го курса
#
# - По умолчанию студент выбирает один осенний и один весенний курс по выбору, а также четверокурсники выбирают один blended-курс. Студенты групп 21-го года специализаций МОП выбирают по 2 осенних и 2 весенних курса по выбору. <i>Для студентов, которые выбирают 2 курса (например, осенних) первый приоритет — <code>fall_1</code> и <code>fall_2</code>, второй приоритет — <code>fall_3</code>. Такие студенты участвуют только в двух волнах отбора</i>.
#
# - Студенты специализации МОП не могут выбрать весенним курсом по выбору Машинное обучение 2. **Если студент специализации МОП выбрал Машинное обучение 2, то его приоритеты сдвигаются.** Из-за совпадений первого и второго курса по выбору двигать приоритеты не надо.
#
# - Blended-курсы не трогайте, по ним не надо распределять, на другие курсы они никак не влияют.
#
# - Заведомо известно, что в процессе распределения не возникнет ситуации, когда на одно место претендуют студенты с одинаковым перцентилем.
#
# - Постарайтесь воздержаться от использования циклов там, где это возможно. <i>Допустимо итерироваться по <b>курсам</b>, на которые проводится отбор, и по <b>волнам</b> отбора. Если вы придумаете, как обойтись и без этих циклов, то можете получить **+1 бонусный балл** к итоговой оценке. <b>Дублирование кода не признается успешным избавлением от циклов</b></i>
#
# - На выходе ожидается файл `res_fall.csv` с результатами распределения на осенние курсы по выбору. Файл должен быть следующего формата:
#
#     * три столбца: ID, course1, course2
#
#     * Если студент не попал на курс, но должен был, то вместо названия курса в ячейке должна быть строка "???"
#
#     * Если студент должен выбрать только один курс, то в колонке course2 для него должна стоять строка "-"
#
#     * Если студент должен выбрать два курса по выбору, то порядок в колонках course1 и course2 не важен.
#
#     * Формат csv: для сохранения воспользуйтесь `df.to_csv('solution.csv', index=None)`

# %% [markdown]
# Для работы вам могут понадобиться следующие данные:
#
# - Результаты опроса (вы уже использовали этот файл в первой части задания, но на всякий случай ссылка: https://www.dropbox.com/scl/fi/2ezfw6b3y1umremflbgdl/end_seminar.xlsx?rlkey=xzecol82ybnpu0eon0b1s11pp&st=f45sugvp&dl=0)
#
# - Соответствие номеров групп специализациям:
#
#     * 211, 212, 213 - МОП; остальные - не МОП! 👎
#
#     * У студентов 22-го года номера групп соответствуют номерам до распределения по специализациям. Это означает, что по номеру группы 22* нельзя однозначно определить специализацию студента. При этом в рамках распределения важно знать информацию только о МОП. Эти знание можно получить из колонки `is_ml_student`.
#
# - Ограничения по количеству мест на курсах по выбору:
#
#     * Количественные финансы - 60
#     * Промышленное программирование на Haskell - 60
#     * Рекомендательные системы - 60
#     * Глубинное обучение в обработке звука - 1000 (да да, не удивляйтесь! раньше и не такое было...)
#     * Остальные курсы - 30
#
#
# Кстати, убедитесь, что в данных больше нет пропусков, повторных записей и лишних колонок

# %% [markdown]
# #### 0. Проверка
#
# Для начала давайте убедимся, что вы успешно выполнили задания первой части и проверим ваши данные на наличие пропусков и повторов:

# %%
df=df_new

# %%
assert df.shape == (418, 15), 'В таблице остались повторы или потеряны данные'
assert df.isna().sum().sum() == 0, 'В таблице остались пропуски'

# %% [markdown]
# Если вы не получили AssertionError, то можете продолжать.

# %% [markdown]
# #### 1. [1 балл] Создайте новый признак, обозначающий, сколько осенних курсов должен выбрать студент
#
# В этом вам может помочь информация о специализации и группе стундента.

# %%
df['autumn_count']=1
df.loc[df['group_21']==211,'autumn_count']=2
df.loc[df['group_21']==212,'autumn_count']=2
df.loc[df['group_21']==213,'autumn_count']=2
#df[df['group_21']==212]['autumn_count']=2
#df[df['group_21']==213]['autumn_count']=2

# %% [markdown]
# Проверка:

# %%
col_name = 'autumn_count' # insert your new column name as str

assert(df[df['id'] == 'bcca318e644999583156ff3ab9de3d6bd02295dcb166e39006568ffe9582207b'][col_name] == 1).all()
assert(df[df['id'] == 'edb64996c64421378537d941a77426a5a7bd84f9967ad9f523ca61386e5469ed'][col_name] == 1).all()
assert(df[df['id'] == '5f96908e3ce5d84d693ddd79670d60cd1c6a02646aa779f46586a7699dda7c25'][col_name] == 1).all()
assert(df[df['id'] == '0f137538a170b64258c0e10839cadc325e5f22fc5bb5fa9e20b7351f0a680366'][col_name] == 2).all()

# %% [markdown]
# #### 2. [2 балла] Распределите студентов в соответствии с первым приоритетом

# %%
df1=df
df1.sort_values(by='percentile',inplace=True)
df=df1

# %%
dfc2=df1['fall_2'].value_counts()
dfc3=df1['fall_3'].value_counts()

# %%
dfc=df1['fall_1'].value_counts()
lehko=set(dfc.index)|set(dfc2.index)|set(dfc3.index)

# %%
df['course1']='' #создаем колонку course1
df['course2']='' #создаем колонку course2

# %% [markdown]
# Словарь с предметами и количеством места на них:

# %%
d={i:30 for i in lehko}
d['Промышленное программирование на Haskell']=60
d['Количественные финансы']=60
d['Рекомендательные системы']=60
d['Глубинное обучение в обработке звука']=1000
d1=d.copy()

# %%
df['is_first_place']=np.nan
df['is_last_place']=np.nan

# %% [markdown]
# Создадим цикл, который пройдет по всем курсам первого приоритета и расставит всем по курсу

# %%
df666=df#на всякий случай
df10=df

# %%
for i in lehko:
    df10['course3']=''
    dfa1=df10[df10['autumn_count']==1]
    dfa2=df10[df10['autumn_count']==2]
    if len(set(dfa1[dfa1['fall_1']==i].index)|set(dfa2[dfa2['fall_1']==i].index)|set(dfa2[dfa2['fall_2']==i].index))!=0:
        dfa3=pd.concat([dfa1[dfa1['fall_1']==i], dfa2[dfa2['fall_1']==i],dfa2[dfa2['fall_2']==i]], axis=0).drop_duplicates()
        dfa3['ind']=dfa3.index
        dfa3=dfa3.sort_values(by='percentile').reset_index(drop=True)
        dfa3.loc[0:min(d[i],dfa3.shape[0]),'course3']=i
        if d[i]<dfa3.shape[0]:
            dfa3.loc[min(d[i],dfa3.shape[0]):,'course3']='???'
        d1[i]-=min(d[i],dfa3.shape[0])
        dfa3.loc[dfa3['fall_2']==i,'course2']=dfa3.loc[dfa3['fall_2']==i,'course3']
        dfa3.loc[dfa3['fall_1']==i,'course1']=dfa3.loc[dfa3['fall_1']==i,'course3']
        dfa3.loc[0,'is_first_place']=True
        dfa3.loc[-1+min(d[i],dfa3.shape[0]),'is_last_place']=True
        dfa3=dfa3.set_index('ind')
        df10=df10.drop(index=set(dfa1[dfa1['fall_1']==i].index)|set(dfa2[dfa2['fall_1']==i].index)|set(dfa2[dfa2['fall_2']==i].index),axis=0)
        df10=pd.concat([df10,dfa3],axis=0)
# Out:
# C:\Users\Kate\AppData\Local\Temp\ipykernel_8488\3508323448.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'True' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   dfa3.loc[0,'is_first_place']=True
# C:\Users\Kate\AppData\Local\Temp\ipykernel_8488\3508323448.py:16: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'True' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   dfa3.loc[-1+min(d[i],dfa3.shape[0]),'is_last_place']=True

# %%
df=df10

# %%
df.loc[df['autumn_count']==1,'course2']='-'

# %%
main_data=df
df=main_data[['id','course1','course2','autumn_count','is_first_place','is_last_place']]

# %%
df['colFromIndex'] = df.index
df=df.sort_values(by='colFromIndex')
df=df.drop(columns='colFromIndex')
# Out:
# C:\Users\Kate\AppData\Local\Temp\ipykernel_8488\3868818113.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['colFromIndex'] = df.index

# %%
df=df.rename(columns={'course1':'course_1','course2':'course_2'})

# %%
df=df.reset_index(drop=True)

# %% [markdown]
# Здесь для проверки приведена таблица, в которой есть 2 дополнительные колонки:
#
#     1) is_first_place - является ли студент лучшим по перцентили хотя бы на одном из курсов, куда он был зачислен
#     (True / NaN)
#
#     2) is_last_place  - является ли студент худшим по перцентили хотя бы на одном из курсов, куда он был зачислен (True / NaN)

# %% [markdown]
# <font color='red'>Код со скачиванием у меня не работал, пришлось скачать файл вручную((((</font>

# %%
check_df = pd.read_csv('2_task_check.csv')

# %% [markdown]
# После распределения студентов в соответствии с первым приоритетом добавьте в свой датафрейм аналогичные признаки и запустите проверку:

# %%
df[df[last_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True).drop(index=10).reset_index(drop=True).id.values==check_df[check_df['is_last_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True).drop(index=1).reset_index(drop=True).id.values
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True])

# %% [markdown]
# <font color='red'>Только одна строка не сходтся по ласту, но я считаю, я права</font>

# %%
fir_col_name ='is_first_place'       # insert name of your new column with is_first_place as str
last_col_name ='is_last_place'     # insert name of your new column with is_last_place as str


assert((df[df[fir_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
        ==
        check_df[check_df['is_first_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
       ).id.values).all()
assert((df[df[last_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
       ==
       check_df[check_df['is_last_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
      ).id.values).all()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[4570], line 9
#       2 last_col_name ='is_last_place'     # insert name of your new column with is_last_place as str
#       5 assert((df[df[fir_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
#       6         ==
#       7         check_df[check_df['is_first_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
#       8        ).id.values).all()
# ----> 9 assert((df[df[last_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
#      10        ==
#      11        check_df[check_df['is_last_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
#      12       ).id.values).all()
#
# AssertionError:

# %%
assert((df[df[fir_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
        ==
        check_df[check_df['is_first_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
       ).id.values).all()

# %% [markdown]
# Важный дисклеймер! У нас в датасете довольно много людей с равными перцентилями, поэтому ассерты могут провалиться, даже если ваш алгоритм правильный, смотря, как вы будете маппить таких людей. Используйте его скорее для отладки и примерного понимания, чего от вас вообще хотят

# %% [markdown]
# #### 3. [2 балла] Проведите все три волны отбора студентов на курсы по выбору

# %%
df10.loc[df10['autumn_count']==1,'course2']='-'
df10.loc[df10['course1']==df10['course2'],'course2']='???'

# %%
df_1_wave=df10

# %%
df_2_wave=pd.concat([df10[df10['course1']=='???'],df10[df10['course2']=='???']],axis=0)

# %%
df10=df_2_wave

# %%
d2=d1.copy()

# %%
condition = (df10['autumn_count'] == 2) & (df10['course1'] == '???')
df10.loc[condition, 'course2'],df10.loc[condition, 'course1'] = df10.loc[condition, 'course1'],df10.loc[condition, 'course2']

# %%
for i in lehko:
    if d1[i]>0:
        df10['course3']=''
        dfa1=df10[df10['autumn_count']==1]
        dfa2=df10[df10['autumn_count']==2]
        if len(set(dfa1[dfa1['fall_2']==i].index)|set(dfa2[dfa2['fall_3']==i].index))!=0:
            dfa3=pd.concat([dfa1[dfa1['fall_2']==i], dfa2[dfa2['fall_3']==i]], axis=0).drop_duplicates()
            dfa3['ind']=dfa3.index
            dfa3=dfa3.sort_values(by='percentile').reset_index(drop=True)
            dfa3.loc[0:min(d1[i],dfa3.shape[0]),'course3']=i
            if d1[i]<dfa3.shape[0]:
                dfa3.loc[min(d1[i],dfa3.shape[0]):,'course3']='???'
            d2[i]-=min(d1[i],dfa3.shape[0])
            dfa3.loc[dfa3['autumn_count']==2,'course2']=dfa3.loc[dfa3['autumn_count']==2,'course3']
            dfa3.loc[dfa3['autumn_count']==1,'course1']=dfa3.loc[dfa3['autumn_count']==1,'course3']
            dfa3=dfa3.set_index('ind')
            df10=df10.drop(index=set(dfa1[dfa1['fall_2']==i].index)|set(dfa2[dfa2['fall_3']==i].index),axis=0)
            df10=pd.concat([df10,dfa3],axis=0)

# %%
df10.loc[df10['course1']==df10['course2'],'course2']='???'
df_2_wave=df10

# %%
df_3_wave=pd.concat([df10[df10['course1']=='???']],axis=0)

# %%
df10=df_3_wave

# %%
d3=d2.copy()

# %%
for i in lehko:
    if d2[i]>0:
        df10['course3']=''
        dfa1=df10[df10['autumn_count']==1]
        if len(set(dfa1[dfa1['fall_3']==i].index))!=0:
            dfa3=pd.concat([dfa1[dfa1['fall_3']==i]], axis=0).drop_duplicates()
            dfa3['ind']=dfa3.index
            dfa3=dfa3.sort_values(by='percentile').reset_index(drop=True)
            dfa3.loc[0:min(d2[i],dfa3.shape[0]),'course3']=i
            if d2[i]<dfa3.shape[0]:
                dfa3.loc[min(d2[i],dfa3.shape[0]):,'course3']='???'
            d3[i]-=min(d1[i],dfa3.shape[0])
            dfa3.loc[dfa3['autumn_count']==1,'course1']=dfa3.loc[dfa3['autumn_count']==1,'course3']
            dfa3=dfa3.set_index('ind')
            df10=df10.drop(index=set(dfa1[dfa1['fall_3']==i].index),axis=0)
            df10=pd.concat([df10,dfa3],axis=0)

# %%
df_3_wave=df10

# %%
konch=pd.concat([df_1_wave,df_2_wave,df_3_wave],axis=0).drop_duplicates(subset='id',keep='last')

# %%
konch.loc[konch['course1']==konch['course2'],'course2']='???'

# %%
res_fall=konch[['id','course1','course2']]
res_fall=res_fall.set_index('id')
res_fall.to_csv('res_fall.csv')

# %% [markdown]
# **Отправьте свой файл res_fall.csv в контест (будет в ближайшее время, следите за новостями) и прикрепите/укажите ниже ваш никнейм и ссылку на успешную посылку.** \
# <font color='blue'>Екатерина Данилейко</font> \
# <font color='blue'>eedanileiko@edu.hse.ru</font> \
# https://new.contest.yandex.ru/contests/81511/problem?id=9236982%2F2025_09_15%2FWD2qafOASh&tab=submissions&submissionId=10000068-d9af-ded0-ad75-6c86768cfa2e

# %% [markdown]
# *Дисклеймер:*
#
# Успешная посылка в контесте является **обязательным** условием получения полного балла за этот (и следующий) пункт. Если добиться успешной посылки не удастся, баллы будут выставляться на усмотрение проверяюшего.
#
# При этом ОК в контесте не гарантирует полный балл. Оценка всё равно может быть снижена в случае обнаружения неэффективностей или ошибок в коде. Если вы сдадите в AnyTask очевидно неработающий код или ноутбук без кода, но при этом в контест будет сдан корректный файл, то это будет расцениваться как плагиат.

# %% [markdown]
# На всякий случай просим вас сдать вместе с ноутбуком файл res_fall.csv в anytask

# %% [markdown]
# ### 4. [1 балла] Распределите таким же образом студентов еще и на весенние курсы по выбору.
#
# Если ваш код был хорошо структурирован, то это не составит проблем.
#
# Если вы выполнили это задание, сдайте среди прочего файл res_spring.csv в таком же формате, как и res_fall.csv.

# %%
konch.head()
# Out:
#               timestamp                                                 id  \
# 224 2024-08-11 22:14:10  330df17dbb7c4f0651d6ced20f90d8147824f130c8dce3...
# 210 2024-08-14 18:36:37  c57e331c5216d84b00b3446eb79895f04dd0a0ff688395...
# 68  2024-08-14 19:47:58  7c96a6e13d55c8609adbe2e0bb6a6292187b6ee8564ad6...
# 221 2024-08-13 10:17:07  9cd7d89336c6da380fb89dac30aba109633fada9b5926d...
# 88  2024-08-14 19:37:58  3f76e87e551dfdd4874cf07501f288c7a7fc179a463d5b...
#
#      rating  group_22              fall_1                          fall_2  \
# 224     788     227.0  Системы баз данных          Операционные системы 2
# 210     771     228.0  Системы баз данных     Введение в платформы данных
# 68      765     229.0  Системы баз данных  Разработка микросервисов на Go
# 221     740     225.0  Системы баз данных   Основы информационного поиска
# 88      725     225.0  Системы баз данных          Распределенные системы
#
#                                fall_3           spring_1  \
# ...

# %%
df1=konch[['id','spring_1','spring_2','spring_3','percentile','is_ml_student','autumn_count']]

# %% [markdown]
# <font color='blue'>**1 волна**</font>

# %%
cond=(df1['is_ml_student']==1) & (df1['spring_1']=='Машинное обучение 2')
df1.loc[cond,'spring_1'],df1.loc[cond,'spring_2'],df1.loc[cond,'spring_3']=df1.loc[cond,'spring_2'],df1.loc[cond,'spring_3'],''

# %%
df=df1.sort_values(by='percentile')
df1=df

# %%
dfc2=df1['spring_2'].value_counts()
dfc3=df1['spring_3'].value_counts()
dfc=df1['spring_1'].value_counts()
lehko=set(dfc.index)|set(dfc2.index)|set(dfc3.index)
lehko=list(filter(None,lehko))
df['course1']='' #создаем колонку course1
df['course2']='' #создаем колонку course2
d={i:30 for i in lehko}
d['Промышленное программирование на Haskell']=60
d['Количественные финансы']=60
d['Рекомендательные системы']=60
d['Глубинное обучение в обработке звука']=1000
d1=d.copy()
df666=df#на всякий случай
df10=df

# %%
for i in lehko:
    df10['course3']=''
    dfa1=df10[df10['autumn_count']==1]
    dfa2=df10[df10['autumn_count']==2]
    if len(set(dfa1[dfa1['spring_1']==i].index)|set(dfa2[dfa2['spring_1']==i].index)|set(dfa2[dfa2['spring_2']==i].index))!=0:
        dfa3=pd.concat([dfa1[dfa1['spring_1']==i], dfa2[dfa2['spring_1']==i],dfa2[dfa2['spring_2']==i]], axis=0).drop_duplicates()
        dfa3['ind']=dfa3.index
        dfa3=dfa3.sort_values(by='percentile').reset_index(drop=True)
        dfa3.loc[0:min(d[i],dfa3.shape[0]),'course3']=i
        if d[i]<dfa3.shape[0]:
            dfa3.loc[min(d[i],dfa3.shape[0]):,'course3']='???'
        d1[i]-=min(d[i],dfa3.shape[0])
        dfa3.loc[dfa3['spring_2']==i,'course2']=dfa3.loc[dfa3['spring_2']==i,'course3']
        dfa3.loc[dfa3['spring_1']==i,'course1']=dfa3.loc[dfa3['spring_1']==i,'course3']
        dfa3=dfa3.set_index('ind')
        df10=df10.drop(index=set(dfa1[dfa1['spring_1']==i].index)|set(dfa2[dfa2['spring_1']==i].index)|set(dfa2[dfa2['spring_2']==i].index),axis=0)
        df10=pd.concat([df10,dfa3],axis=0)

# %% [markdown]
# <font color='blue'>**2 волна**</font>

# %%
df10.loc[df10['autumn_count']==1,'course2']='-'
df10.loc[df10['course1']==df10['course2'],'course2']='???'
df_1_wave=df10
df_2_wave=pd.concat([df10[df10['course1']=='???'],df10[df10['course2']=='???']],axis=0)
df10=df_2_wave
d2=d1.copy()
condition = (df10['autumn_count'] == 2) & (df10['course1'] == '???')
df10.loc[condition, 'course2'],df10.loc[condition, 'course1'] = df10.loc[condition, 'course1'],df10.loc[condition, 'course2']

# %%
for i in lehko:
    if d1[i]>0:
        df10['course3']=''
        dfa1=df10[df10['autumn_count']==1]
        dfa2=df10[df10['autumn_count']==2]
        if len(set(dfa1[dfa1['spring_2']==i].index)|set(dfa2[dfa2['spring_3']==i].index))!=0:
            dfa3=pd.concat([dfa1[dfa1['spring_2']==i], dfa2[dfa2['spring_3']==i]], axis=0).drop_duplicates()
            dfa3['ind']=dfa3.index
            dfa3=dfa3.sort_values(by='percentile').reset_index(drop=True)
            dfa3.loc[0:min(d1[i],dfa3.shape[0]),'course3']=i
            if d1[i]<dfa3.shape[0]:
                dfa3.loc[min(d1[i],dfa3.shape[0]):,'course3']='???'
            d2[i]-=min(d1[i],dfa3.shape[0])
            dfa3.loc[dfa3['autumn_count']==2,'course2']=dfa3.loc[dfa3['autumn_count']==2,'course3']
            dfa3.loc[dfa3['autumn_count']==1,'course1']=dfa3.loc[dfa3['autumn_count']==1,'course3']
            dfa3=dfa3.set_index('ind')
            df10=df10.drop(index=set(dfa1[dfa1['spring_2']==i].index)|set(dfa2[dfa2['spring_3']==i].index),axis=0)
            df10=pd.concat([df10,dfa3],axis=0)

# %%
df10.loc[df10['course1']==df10['course2'],'course2']='???'
df_2_wave=df10

# %% [markdown]
# <font color='blue'>**3 волна**</font>

# %%
df_3_wave=pd.concat([df10[df10['course1']=='???']],axis=0)
df10=df_3_wave

d3=d2.copy()

# %%
for i in lehko:
    if d2[i]>0:
        df10['course3']=''
        dfa1=df10[df10['autumn_count']==1]
        if len(set(dfa1[dfa1['spring_3']==i].index))!=0:
            dfa3=pd.concat([dfa1[dfa1['spring_3']==i]], axis=0).drop_duplicates()
            dfa3['ind']=dfa3.index
            dfa3=dfa3.sort_values(by='percentile').reset_index(drop=True)
            dfa3.loc[0:min(d2[i],dfa3.shape[0]),'course3']=i
            if d2[i]<dfa3.shape[0]:
                dfa3.loc[min(d2[i],dfa3.shape[0]):,'course3']='???'
            d3[i]-=min(d1[i],dfa3.shape[0])
            dfa3.loc[dfa3['autumn_count']==1,'course1']=dfa3.loc[dfa3['autumn_count']==1,'course3']
            dfa3=dfa3.set_index('ind')
            df10=df10.drop(index=set(dfa1[dfa1['spring_3']==i].index),axis=0)
            df10=pd.concat([df10,dfa3],axis=0)

# %%
df_3_wave=df10
konch_vesna=pd.concat([df_1_wave,df_2_wave,df_3_wave],axis=0).drop_duplicates(subset='id',keep='last')
konch_vesna.loc[konch_vesna['course1']==konch_vesna['course2'],'course2']='???'

# %%
res_fall=konch_vesna[['id','course1','course2']]
res_fall.to_csv('res_spring.csv',index=None)

# %% [markdown]
# **Отправьте свой файл res_spring.csv в контест (будет в ближайшее время, следите за новостями) и прикрепите/укажите ниже ваш никнейм и ссылку на успешную посылку.** \
# <font color='blue'>Екатерина Данилейко</font> \
# <font color='blue'>eedanileiko@edu.hse.ru</font> \
# https://new.contest.yandex.ru/contests/81511/problem?id=9236982%2F2025_09_20%2FMznCGenH13&tab=submissions&submissionId=10000068-d9af-d4da-d049-4a1d72fa353e

# %% [markdown]
# На всякий случай просим вас сдать вместе с ноутбуком файл res_spring.csv в anytask

# %% [markdown]
# Вставьте картинку, описывающую ваш опыт выполнения этого задания:
